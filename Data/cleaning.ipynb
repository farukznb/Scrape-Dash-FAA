# %%
import pandas as pd

v = pd.read_csv('motos.csv', sep=',')
v.columns
# Out:
# Index(['web-scraper-order', 'web-scraper-start-url', 'articles_links',
#        'articles_links-href', 'Brand', 'Price', 'Address', 'image_link-src'],
#       dtype='object')

# %%
vh = v.drop(['web-scraper-order', 'web-scraper-start-url', 'articles_links', 'articles_links-href'], axis=1)

# %%
v.shape
# Out:
# (435, 8)

# %%
vh.isna()
# Out:
#      Brand  Price  Address  image_link-src
# 0    False  False    False           False
# 1    False  False    False           False
# 2    False  False    False           False
# 3    False  False    False           False
# 4    False  False    False           False
# ..     ...    ...      ...             ...
# 430   True   True     True            True
# 431   True   True     True            True
# 432   True   True     True            True
# 433   True   True     True            True
# 434   True   True     True            True
#
# [435 rows x 4 columns]

# %%
L = pd.read_csv('vehicule_location.csv', sep=',')
Loc = L.drop(['web-scraper-order', 'web-scraper-start-url', 'articles_links', 'articles_links-href'], axis=1)
Loc
# Out:
#                                                  Brand          Price  \
# 0    Location d'une  citroen c4Logements de qualité...   20.000  FCFA
# 1    Location de voitures et mini bus avec chauffeu...   50.000  FCFA
# 2    Sen service location loue des voiture des marq...   30.000  FCFA
# 3                                  Toyota yaris  sedan   20.000  FCFA
# 4                                          Nissan juke   50.000  FCFA
# ..                                                 ...            ...
# 185                 Location Ford Escape titanium 2014   35.000  FCFA
# 186                                    Subaru forester   35.000  FCFA
# 187                                Firdawsi automobile  250.000  FCFA
# 188                                      Dodge caravan   35.000  FCFA
# 189                                   Location voiture   25.000  FCFA
#
#           Adress                                     image_link-src
# ...

# %%
T = pd.read_excel('vente_telephone.xlsx')
Tel = T.drop(['web-scraper-order', 'web-scraper-start-url', 'container',
     'container-href'], axis=1)
Tel
# Out:
#                                   brand          price    address  \
# 0                       Iphone 6 simple  130.000  FCFA    Plateau
# 1            Vends un Tecno camon x pro  135.000  FCFA    Plateau
# 2                            Ipad air 1  100.000  FCFA    Plateau
# 3    Samsung galaxy grand prime plus 4g   57.000  FCFA    Plateau
# 4                                   NaN            NaN        NaN
# ..                                  ...            ...        ...
# 491                            iphone x  315.000  FCFA  Dieuppeul
# 492                           iphone 6s  115.000  FCFA  Dieuppeul
# 493                        INVENS Max 8   45.000  FCFA    Plateau
# 494                    Téléphones Tecno   70.000  FCFA    Point E
# 495                              iPhone  180.000  FCFA      Dakar
#
#                                         image_link-src
# 0    media/annonces/pics/9dc1cf2ff3a464553891afc718...
# 1    media/annonces/pics/21192c68f3734e184c4a49a3d2...
# ...
